# %%
import matplotlib.pyplot as mp

# %%
sem = [1,2,3,4]
marks = [69,75,73,83]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('dark_background')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [69,75,73,83]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('_mpl-gallery')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [69,75,73,83]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('ggplot')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [69,75,73,83]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('bmh')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [69,75,73,83]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('_classic_test_patch')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [69,75,73,83]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('Solarize_Light2')
mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [69,75,73,83]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('grayscale')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [69,75,73,83]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('seaborn-v0_8')

mp.grid(True)

mp.show()

# %%
sem = [1,2,3,4]
marks = [69,75,73,83]
mp.plot(sem,marks)
mp.ylabel("Marks")
mp.xlabel("SEM")
mp.title("Performance")
mp.style.use('seaborn-v0_8-colorblind')

mp.grid(True)

mp.show()
